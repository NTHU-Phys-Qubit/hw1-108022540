# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1D Random walk
#
# We will concider two kinds of 1D random talk.
# * $dx$ is uniformly distributed between $[-1/2, +1/2]$.
# * $dx=+1$ with probability 1/2 and $dx=-1$ with probability 1/2.
#
# For both kinds of the 1D random walk, you should do the following:
# * Plot a single trajectory.
# * Plot the histogram of the end point for an ensemble of trajectories.

# %%
number_final = []
y = 0
p = [y]
for i in range (10000):
    dy  = np.random.random()-0.5
    y   = y + dy
    p.append(y)

for j in range(2000):
    y = 0
    for i in range (1000):
        dy  = np.random.random()-0.5
        y   = y + dy
    number_final.append(y)
    
plt.figure(figsize=(10,5))
plt.plot(p)
plt.title("1D random walk")
plt.xlabel("time")
plt.ylabel("position")

plt.figure(figsize=(10,5))
plt.hist(number_final,bins=100)
plt.xlabel("position")
plt.ylabel("times")
# Out:
# Text(0, 0.5, 'times')
